# %% [markdown]
# <img src='https://drive.google.com/uc?export=view&id=1i_XBoCPReEtySdjypk36ux3qIAwufet5' height=400 >

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('../input/google-stock-prediction/GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %% [markdown]
# # Data Pre-Processing

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %% [markdown]
# # Creating LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 7s 93ms/step - loss: 0.0056 - mean_absolute_error: 0.0503 - val_loss: 0.0071 - val_mean_absolute_error: 0.0690
# Epoch 2/80
# 30/30 [==============================] - 2s 51ms/step - loss: 7.7516e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0034 - val_mean_absolute_error: 0.0467
# Epoch 3/80
# 30/30 [==============================] - 1s 50ms/step - loss: 5.6197e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0027 - val_mean_absolute_error: 0.0415
# Epoch 4/80
# 30/30 [==============================] - 1s 49ms/step - loss: 5.3669e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0030 - val_mean_absolute_error: 0.0440
# Epoch 5/80
# 30/30 [==============================] - 1s 49ms/step - loss: 5.6678e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0020 - val_mean_absolute_error: 0.0359
# Epoch 6/80
# 30/30 [==============================] - 2s 57ms/step - loss: 5.3677e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0066 - val_mean_absolute_error: 0.0691
# Epoch 7/80
# 30/30 [==============================] - 2s 51ms/step - loss: 4.5404e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0020 - val_mean_absolute_error: 0.0358
# Epoch 8/80
# 30/30 [==============================] - 1s 49ms/step - loss: 4.4762e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0024 - val_mean_absolute_error: 0.0383
# Epoch 9/80
# 30/30 [==============================] - 2s 50ms/step - loss: 4.4786e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0028 - val_mean_absolute_error: 0.0426
# Epoch 10/80
# 30/30 [==============================] - 1s 49ms/step - loss: 3.9898e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0027 - val_mean_absolute_error: 0.0419
# Epoch 11/80
# 30/30 [==============================] - 1s 49ms/step - loss: 3.9519e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0021 - val_mean_absolute_error: 0.0358
# Epoch 12/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.8637e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0022 - val_mean_absolute_error: 0.0365
# Epoch 13/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.9799e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0038 - val_mean_absolute_error: 0.0505
# Epoch 14/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.8863e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0027 - val_mean_absolute_error: 0.0411
# Epoch 15/80
# 30/30 [==============================] - 2s 52ms/step - loss: 3.4937e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0050 - val_mean_absolute_error: 0.0588
# Epoch 16/80
# 30/30 [==============================] - 2s 50ms/step - loss: 3.1139e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0043 - val_mean_absolute_error: 0.0539
# Epoch 17/80
# 30/30 [==============================] - 1s 49ms/step - loss: 3.0695e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0038 - val_mean_absolute_error: 0.0490
# Epoch 18/80
# 30/30 [==============================] - 2s 50ms/step - loss: 3.0937e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0041 - val_mean_absolute_error: 0.0509
# Epoch 19/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.1792e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0070 - val_mean_absolute_error: 0.0705
# Epoch 20/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.1657e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0043 - val_mean_absolute_error: 0.0515
# Epoch 21/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.9154e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0045 - val_mean_absolute_error: 0.0537
# Epoch 22/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.6171e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0059 - val_mean_absolute_error: 0.0626
# Epoch 23/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.8775e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0038 - val_mean_absolute_error: 0.0480
# Epoch 24/80
# 30/30 [==============================] - 1s 49ms/step - loss: 3.0178e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0026 - val_mean_absolute_error: 0.0389
# Epoch 25/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.0017e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0032 - val_mean_absolute_error: 0.0433
# Epoch 26/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.6809e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0031 - val_mean_absolute_error: 0.0426
# Epoch 27/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.5715e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0048 - val_mean_absolute_error: 0.0567
# Epoch 28/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.5217e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0059 - val_mean_absolute_error: 0.0639
# Epoch 29/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.5240e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0071 - val_mean_absolute_error: 0.0712
# Epoch 30/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.4102e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0036 - val_mean_absolute_error: 0.0466
# Epoch 31/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.4987e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0016 - val_mean_absolute_error: 0.0303
# Epoch 32/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.8750e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0024 - val_mean_absolute_error: 0.0378
# Epoch 33/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.2934e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0034 - val_mean_absolute_error: 0.0470
# Epoch 34/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.4328e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0044 - val_mean_absolute_error: 0.0538
# Epoch 35/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.3894e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0047 - val_mean_absolute_error: 0.0557
# Epoch 36/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.3635e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0029 - val_mean_absolute_error: 0.0411
# Epoch 37/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.6352e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0093 - val_mean_absolute_error: 0.0835
# Epoch 38/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.8550e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0021 - val_mean_absolute_error: 0.0350
# Epoch 39/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.1904e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0030 - val_mean_absolute_error: 0.0434
# Epoch 40/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.1436e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0025 - val_mean_absolute_error: 0.0387
# Epoch 41/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.1236e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0035 - val_mean_absolute_error: 0.0479
# Epoch 42/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.1176e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0025 - val_mean_absolute_error: 0.0386
# Epoch 43/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.1124e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0016 - val_mean_absolute_error: 0.0307
# Epoch 44/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.2420e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0036 - val_mean_absolute_error: 0.0485
# Epoch 45/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.8804e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0028 - val_mean_absolute_error: 0.0418
# Epoch 46/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.9576e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0044 - val_mean_absolute_error: 0.0548
# Epoch 47/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.4179e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0020 - val_mean_absolute_error: 0.0342
# Epoch 48/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.9895e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0028 - val_mean_absolute_error: 0.0430
# Epoch 49/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.9739e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 50/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.0212e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 51/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.0088e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0024 - val_mean_absolute_error: 0.0397
# Epoch 52/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.7516e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0024 - val_mean_absolute_error: 0.0400
# Epoch 53/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.8103e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 54/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.8301e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0030 - val_mean_absolute_error: 0.0455
# Epoch 55/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.8180e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 56/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.7636e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0028 - val_mean_absolute_error: 0.0433
# Epoch 57/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.6375e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0025 - val_mean_absolute_error: 0.0405
# Epoch 58/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.0649e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0024 - val_mean_absolute_error: 0.0403
# Epoch 59/80
# 30/30 [==============================] - 1s 50ms/step - loss: 2.0344e-04 - mean_absolute_error: 0.0104 - val_loss: 9.3166e-04 - val_mean_absolute_error: 0.0230
# Epoch 60/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.8910e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0029 - val_mean_absolute_error: 0.0444
# Epoch 61/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.7497e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 62/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.7021e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0018 - val_mean_absolute_error: 0.0338
# Epoch 63/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.6542e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0017 - val_mean_absolute_error: 0.0321
# Epoch 64/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.0230e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0023 - val_mean_absolute_error: 0.0387
# Epoch 65/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.6164e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 66/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.7374e-04 - mean_absolute_error: 0.0095 - val_loss: 6.2716e-04 - val_mean_absolute_error: 0.0198
# Epoch 67/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.6145e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 68/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.4672e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 69/80
# 30/30 [==============================] - 2s 55ms/step - loss: 1.6194e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0018 - val_mean_absolute_error: 0.0331
# Epoch 70/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.4199e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 71/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.5207e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0023 - val_mean_absolute_error: 0.0379
# Epoch 72/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.4448e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0016 - val_mean_absolute_error: 0.0307
# Epoch 73/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.4421e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0020 - val_mean_absolute_error: 0.0358
# Epoch 74/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.4833e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0016 - val_mean_absolute_error: 0.0312
# Epoch 75/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.3694e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0027 - val_mean_absolute_error: 0.0416
# Epoch 76/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.3736e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0030 - val_mean_absolute_error: 0.0453
# Epoch 77/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.3269e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0027 - val_mean_absolute_error: 0.0418
# Epoch 78/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.3163e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0017 - val_mean_absolute_error: 0.0319
# Epoch 79/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.3561e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0022 - val_mean_absolute_error: 0.0374
# Epoch 80/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.4315e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 15ms/step
# array([[0.48569533, 0.4845146 ],
#        [0.49126032, 0.49023044],
#        [0.4957951 , 0.49483317],
#        [0.5105635 , 0.5089822 ],
#        [0.52076876, 0.51940036]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1571.4402, 1566.2303],
#        [1581.7573, 1576.8237],
#        [1590.1644, 1585.3541],
#        [1617.5438, 1611.577 ],
#        [1636.4636, 1630.8855]], dtype=float32)

# %% [markdown]
# # Visualizing predicted and actual data

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1571.440186      1566.230347
# 2020-08-25  1582.07  1608.22     1581.757324      1576.823730
# 2020-08-26  1608.00  1652.38     1590.164429      1585.354126
# 2020-08-27  1653.68  1634.33     1617.543823      1611.577026
# 2020-08-28  1633.49  1644.41     1636.463623      1630.885498

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# # Predicting upcoming 10 days

# %%
# Creating a dataframe and adding 10 days to existing index 

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2347.224854      2347.576660
# 2021-06-10  2494.01  2521.60     2351.583740      2354.789062
# 2021-06-11  2524.92  2513.93     2355.499512      2359.831299
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
